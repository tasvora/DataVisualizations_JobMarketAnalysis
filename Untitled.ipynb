# %%
# Dependencies
# ----------------------------------
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:postgres@localhost:5432/Jobs')
connection = engine.connect()

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float 
from sqlalchemy.ext.automap import automap_base
# Pandas
import pandas as pd

# Matplotlib
import matplotlib.pyplot as plt
from matplotlib import style
style.use('bmh')
# NumPy
import numpy as np

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['region', 'indeed_jobs_byregion', 'indeed_jobs', 'glassdoor_jobs']

# %%
indeed_data = pd.read_sql("SELECT * FROM indeed_jobs", connection)
indeed_data.head()
# Out:
#                    company_name           title  \
# 0   Universal Screen Arts, Inc.  Data Scientist
# 1           Race Winning Brands    Data Analyst
# 2  LeafFilter Gutter Protection    Data Analyst
# 3                   T-CETRA LLC    Data Analyst
# 4               Harley-Davidson    Data Analyst
#
#                                     job_title  \
# 0  Marketing Manager - Print & Data Analytics
# 1                                Data Analyst
# 2     Human Resources Data Analyst - Contract
# 3                         Data Analyst Tier I
# 4                                Data Analyst
#
#                                          job_summary         city state  id
# 0  Attentive to detail and high level of accuracy...       Hudson    OH   1
# 1  Race Winning Brands is a leader in developing ...       Mentor    OH   2
# 2  This is a highly collaborative role where you ...       Hudson    OH   3
# 3  We're constantly developing new and creative w...       Dublin    OH   4
# 4  Typically requires a minimum of 3 years of rel...  Valley View    OH   5

# %%
# Query All Records in the Table

region_df = pd.read_sql("SELECT * FROM region", connection)
region_df.head()
#indeed_data.head()
#region_df.head()
indeed_byregion_df = pd.read_sql("SELECT * FROM indeed_jobs_byregion", connection)
indeed_byregion_df.head()
# Out:
#                         company           title  \
# 0   Universal Screen Arts, Inc.  Data Scientist
# 1           Race Winning Brands    Data Analyst
# 2  LeafFilter Gutter Protection    Data Analyst
# 3                   T-CETRA LLC    Data Analyst
# 4               Harley-Davidson    Data Analyst
#
#                                     job_title  \
# 0  Marketing Manager - Print & Data Analytics
# 1                                Data Analyst
# 2     Human Resources Data Analyst - Contract
# 3                         Data Analyst Tier I
# 4                                Data Analyst
#
#                                          job_summary         city state  \
# 0  Attentive to detail and high level of accuracy...       Hudson    OH
# 1  Race Winning Brands is a leader in developing ...       Mentor    OH
# 2  This is a highly collaborative role where you ...       Hudson    OH
# 3  We're constantly developing new and creative w...       Dublin    OH
# 4  Typically requires a minimum of 3 years of rel...  Valley View    OH
#
#   state1   region  id
# 0   Ohio  Midwest   1
# 1   Ohio  Midwest   2
# 2   Ohio  Midwest   3
# 3   Ohio  Midwest   4
# 4   Ohio  Midwest   5

# %%
region_df['state']=region_df['state'].str.strip()
indeed_data['state']=indeed_data['state'].str.strip()
indeed_byregion_df = indeed_byregion_df[indeed_byregion_df["region"] == "West"]
indeed_byregion_df.head()
# Out:
#                        company         title                     job_title  \
# 58                         BRS  Data Analyst             Sr. Data Analyst*
# 490                    Cequint  Data Analyst                  Data Analyst
# 605                      WSECU  Data Analyst      Digital Business Analyst
# 630  Amazon Web Services, Inc.  Data Analyst  Business Analyst (Start-Ups)
# 631                  CorneaGen  Data Analyst              Business Analyst
#
#                                            job_summary     city state  \
# 58   Able to write complex SQL using a variety of U...     Kent    WA
# 490  The Splunk Analyst is responsible for supporti...  Seattle    WA
# 605  We look forward to reviewing your application!...  Olympia    WA
# 630  Successful candidates will be analytical with ...  Seattle    WA
# 631  3 to 5 years of experience in computer science...  Seattle    WA
#
#           state1 region   id
# 58    Washington   West   59
# 490   Washington   West  491
# 605   Washington   West  606
# 630   Washington   West  631
# 631   Washington   West  632

# %%
states = region_df["state"].unique()
states
# Out:
# array(['AK', 'AZ', 'CA', 'CO', 'HI', 'ID', 'MO', 'NV', 'NM', 'OR', 'UT',
#        'WA', 'WY', 'IL', 'IN', 'IA', 'KS', 'MI', 'MN', 'NE', 'ND', 'OH',
#        'SD', 'WI', 'AL', 'AR', 'DE', 'FL', 'GA', 'KY', 'LA', 'MD', 'MS',
#        'OK', 'NC', 'SC', 'TN', 'TX', 'VA', 'WV', 'CT', 'ME', 'NH', 'MA',
#        'NJ', 'NY', 'PA', 'RI', 'VT'], dtype=object)

# %%
indeed_df = pd.merge(indeed_data, region_df,how="inner",on="state")
indeed_df.head()
# Out:
#                    company_name           title  \
# 0   Universal Screen Arts, Inc.  Data Scientist
# 1           Race Winning Brands    Data Analyst
# 2  LeafFilter Gutter Protection    Data Analyst
# 3                   T-CETRA LLC    Data Analyst
# 4               Harley-Davidson    Data Analyst
#
#                                     job_title  \
# 0  Marketing Manager - Print & Data Analytics
# 1                                Data Analyst
# 2     Human Resources Data Analyst - Contract
# 3                         Data Analyst Tier I
# 4                                Data Analyst
#
#                                          job_summary         city state  id_x  \
# 0  Attentive to detail and high level of accuracy...       Hudson    OH     1
# 1  Race Winning Brands is a leader in developing ...       Mentor    OH     2
# 2  This is a highly collaborative role where you ...       Hudson    OH     3
# 3  We're constantly developing new and creative w...       Dublin    OH     4
# 4  Typically requires a minimum of 3 years of rel...  Valley View    OH     5
#
#   state1   region  id_y
# 0   Ohio  Midwest    23
# 1   Ohio  Midwest    23
# 2   Ohio  Midwest    23
# 3   Ohio  Midwest    23
# 4   Ohio  Midwest    23

# %%
indeed_df.to_csv("indeed_jobs_byregion.csv")

# %%
region = indeed_df["region"].unique()
region
# Out:
# array([], dtype=object)

# %%
indeed_df[indeed_df["region"] == "South"]
# Out:
# Empty DataFrame
# Columns: [company_name, title, job_title, job_summary, city, state, id_x, state1, region, id_y]
# Index: []

# %%
states = indeed_df["state"].unique()
states
# Out:
# array([], dtype=object)

# %%
job_title = indeed_df["job_title"].unique()
job_title
# Out:
# array([], dtype=object)

# %%
states_grouped = indeed_df.groupby("state")
states_grouped.count()
# Out:
# Empty DataFrame
# Columns: [company_name, title, job_title, job_summary, city, id_x, state1, region, id_y]
# Index: []

# %%
indeed_df[indeed_df["state"] == "NY"]
# Out:
# Empty DataFrame
# Columns: [company_name, title, job_title, job_summary, city, state, id_x, state1, region, id_y]
# Index: []
